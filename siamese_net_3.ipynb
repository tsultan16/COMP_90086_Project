# %%
import random, os
from pathlib import Path
import numpy  as np

# do this before importing tensorflow to get rid of annoying warning messages
import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf
from tensorflow.keras import applications
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import Model
from tensorflow.keras.applications import ResNet50V2 
import matplotlib.pyplot as plt

# %%
# specify image size
target_shape = (200,200)   #(245, 200)

# %% [markdown]
# #### Data Preparation
#
# #### (Also need to do some cleaning for the validation set: need to also remove duplicates from left and right image sets, because we don't want to have any left image to have multiple right image counterparts and vice versa)

# %%
anchor_images_path = "./dataset/left/"
positive_images_path = "./dataset/right/"
batch_size = 32
num_negatives = 15 # number of negative images for each anchor image

# %%
"""
    load image jpeg image from file and resize into the target shape
"""
def preprocess_image(filename):
    img = tf.io.read_file(filename)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, target_shape)
    return img

""" 
    preprocess a triplet of images given their filenames
"""
def preprocess_triplets(anchor, positive, negative):
    return (preprocess_image(anchor), preprocess_image(positive), preprocess_image(negative))

# %% [markdown]
# #### Create dataset in which num_negatives triplets will have the same anchor and positive but different negative image

# %%
# load anchor and positive images (make sure they're in the right order) 
anchor_images = sorted([str(anchor_images_path + f) for f in os.listdir(anchor_images_path)])
positive_images = sorted([str(positive_images_path + f) for f in os.listdir(positive_images_path)])
image_count = len(anchor_images)

# split into training and validation sets
num_train = int(0.8*image_count)
num_val = image_count - num_train
anchor_images_train = anchor_images[:num_train]
anchor_images_val = anchor_images[num_train:]
positive_images_train = positive_images[:num_train]
positive_images_val = positive_images[num_train:]

# %%
# To generate the list of negative images, let's randomize the list of
# available images and concatenate them together.

negative_images_train = anchor_images_train + positive_images_train
np.random.RandomState(seed=32).shuffle(negative_images_train)
negative_images_val = anchor_images_val + positive_images_val
np.random.RandomState(seed=32).shuffle(negative_images_val)

# randomly sample num_negatives+2 negative images for each anchor
# (we sample an extra two images to make sure we don't include any duplicates
# of the positive or anchor image in the negative images set)
zipped_set_train = []
for i in range(0, num_train):
    # randomly sample num_negatives+2 images without replacement
    negative_set = random.sample(negative_images_train, num_negatives+2)
    # remove any duplicates
    negative_set = [img for img in negative_set if img != anchor_images_train[i] and img != positive_images_train[i]] 
    negative_set = negative_set[:num_negatives]

    for negative_img in negative_set:
        zipped_set_train.append((anchor_images_train[i], positive_images_train[i], negative_img))    

anchor_images_train = [zipped[0] for zipped in zipped_set_train]
positive_images_train = [zipped[1] for zipped in zipped_set_train]
negative_images_train = [zipped[2] for zipped in zipped_set_train]
image_count_train = len(anchor_images_train)


zipped_set_val = []
for i in range(0, num_val):
    # randomly sample num_negatives+2 images without replacement
    negative_set = random.sample(negative_images_val, num_negatives+2)
    # remove any duplicates
    negative_set = [img for img in negative_set if img != anchor_images_val[i] and img != positive_images_val[i]] 
    negative_set = negative_set[:num_negatives]

    for negative_img in negative_set:
        zipped_set_val.append((anchor_images_val[i], positive_images_val[i], negative_img))    


anchor_images_val = [zipped[0] for zipped in zipped_set_val]
positive_images_val = [zipped[1] for zipped in zipped_set_val]
negative_images_val = [zipped[2] for zipped in zipped_set_val]
image_count_val = len(anchor_images_val)


# create tensorflow datasets
anchor_dataset_train = tf.data.Dataset.from_tensor_slices(anchor_images_train)
positive_dataset_train = tf.data.Dataset.from_tensor_slices(positive_images_train)
negative_dataset_train = tf.data.Dataset.from_tensor_slices(negative_images_train)
# create a triplet dataset
dataset_train = tf.data.Dataset.zip((anchor_dataset_train, positive_dataset_train, negative_dataset_train))
dataset_train = dataset_train.shuffle(buffer_size=1024)
# convert filenames to preprocessed images
dataset_train = dataset_train.map(preprocess_triplets) 

anchor_dataset_val = tf.data.Dataset.from_tensor_slices(anchor_images_val)
positive_dataset_val = tf.data.Dataset.from_tensor_slices(positive_images_val)
# create a negative dataset from the combined shuffled images
negative_dataset_val = tf.data.Dataset.from_tensor_slices(negative_images_val)
# create a triplet dataset
dataset_val = tf.data.Dataset.zip((anchor_dataset_val, positive_dataset_val, negative_dataset_val))
dataset_val = dataset_val.shuffle(buffer_size=1024)
# convert filenames to preprocessed images
dataset_val = dataset_val.map(preprocess_triplets) 

# create batches
train_dataset = dataset_train.batch(batch_size, drop_remainder=False)
train_dataset = train_dataset.prefetch(16)
val_dataset = dataset_val.batch(batch_size, drop_remainder=False)
val_dataset = val_dataset.prefetch(16)

# %% [markdown]
# #### Visualising the dataset

# %%
def visualize(anchor, positive, negative_set):
    
    def show(ax, image):
        ax.imshow(image)
        ax.axis('off')
        

    fig = plt.figure(figsize=(8, 4))
    axs = fig.subplots(3, 3)
        
    for i in range(3):
        show(axs[i, 0], anchor[i])
        show(axs[i, 1], positive[i])
        show(axs[i, 2], negative_set[i])


visualize(*list(train_dataset.take(1).as_numpy_iterator())[0])

# %% [markdown]
# #### Feature extractor network
#
# We will use ResNet50V2, pretrained on ImageNet, to extract features from the images. All layers preceding `conv5_block1_out` will be frozen, the weights in the remaining layers above will be fine-tuned

# %%
feature_dims = 128

base_cnn = ResNet50V2(weights="imagenet", input_shape=target_shape + (3,), include_top=False) # we do not include the ResNet50 output layer

#base_cnn.summary()

# %%
# add some dense layers on top of resnet 
flatten = layers.Flatten() (base_cnn.output)
output = layers.Dense(512, activation='relu')(flatten)
output = layers.BatchNormalization()(output)
output = layers.Dense(256, activation='relu')(flatten)
output = layers.BatchNormalization()(output)
output = layers.Dense(feature_dims, activation='relu')(flatten)

# combine into a new model
feature_extractor = Model(base_cnn.input, output, name="feature_extractor")

# freeze the weights up to layer conv5_block1_out
trainable = False
for layer in base_cnn.layers:
    if layer.name == "conv5_block1_out":
        trainable = True
    layer.trainable = trainable

feature_extractor.summary()
# Out:
# Model: "feature_extractor"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 206, 206, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 100, 100, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 102, 102, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 50, 50, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 50, 50, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 50, 50, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 50, 50, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 50, 50, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 50, 50, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 52, 52, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 50, 50, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 50, 50, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 50, 50, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 50, 50, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 50, 50, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 50, 50, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 50, 50, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 50, 50, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 50, 50, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 50, 50, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 50, 50, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 52, 52, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 50, 50, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 50, 50, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 50, 50, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 50, 50, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 50, 50, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 50, 50, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 50, 50, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 50, 50, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 50, 50, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 50, 50, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 52, 52, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 25, 25, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 25, 25, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 25, 25, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 25, 25, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 25, 25, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 25, 25, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 27, 27, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 25, 25, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 25, 25, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 25, 25, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 25, 25, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 25, 25, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 25, 25, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 25, 25, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 25, 25, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 27, 27, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 25, 25, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 25, 25, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 25, 25, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 25, 25, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 25, 25, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 25, 25, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 25, 25, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 27, 27, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 25, 25, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 25, 25, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 25, 25, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 25, 25, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 25, 25, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 25, 25, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 25, 25, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 25, 25, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 25, 25, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 27, 27, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 13, 13, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 13, 13, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 13, 13, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 13, 13, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 13, 13, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 13, 13, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 15, 15, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 13, 13, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 13, 13, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 13, 13, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 13, 13, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 13, 13, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 13, 13, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 13, 13, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 15, 15, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 13, 13, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 13, 13, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 13, 13, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 13, 13, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 13, 13, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 13, 13, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 15, 15, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 13, 13, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 13, 13, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 13, 13, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 13, 13, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 13, 13, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 13, 13, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 15, 15, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 13, 13, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 13, 13, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 13, 13, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 13, 13, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 13, 13, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 13, 13, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 15, 15, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 13, 13, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 13, 13, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 13, 13, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 13, 13, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 13, 13, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 13, 13, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 13, 13, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 13, 13, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 15, 15, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  flatten (Flatten)              (None, 100352)       0           ['post_relu[0][0]']
#
#  dense_2 (Dense)                (None, 128)          12845184    ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 36,409,984
# Trainable params: 21,778,560
# Non-trainable params: 14,631,424
# __________________________________________________________________________________________________

# %% [markdown]
# #### Siamese network with custom training loop
#
# The siamese network takes each of the triplet images, extracts features and outputs the L2-distance between the achor image and positive and negative images. The triplet loss function is used to compute the loss, defined as follows:
#
# $L(A,P,N) = Max(Dist(A,P) - Dist(A,N) + margin, 0.0)$

# %%
"""
    A custom layer for computing the distance between extracted features of anchor image and positive/negative images
"""
class DistanceLayer(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, positive, negative_set):
        # compute l2-distance between anchor and positive image
        ap_distance = tf.reduce_sum(tf.square(anchor - positive), -1)
        # compute average l2-distance between anchor and negative images
        an_distance = tf.reduce_mean(tf.reduce_sum(tf.square(anchor - negative_set), -1), -1)
        return (ap_distance, an_distance)
    

anchor_input = layers.Input(shape=target_shape + (3,), name="anchor")    
positive_input = layers.Input(shape=target_shape + (3,), name="positive")    
negative_input = layers.Input(shape=target_shape + (3,), name="negative")    

distances = DistanceLayer()(feature_extractor(anchor_input), feature_extractor(positive_input), feature_extractor(negative_input))

# define the siamese network model
siamese_network = Model(inputs=[anchor_input, positive_input, negative_input], outputs = distances)

# %%
# define custom training loop
class SiameseModel(Model):
    def __init__(self, siamese_network, margin=0.5):
        super().__init__()
        self.siamese_network = siamese_network
        self.margin = margin
        self.loss_tracker = metrics.Mean(name="loss")
        self.accuracy_tracker = metrics.Mean(name="accuracy")
  

    def call(self, inputs):    
        return self.siamese_network(inputs)
    

    # custom training step    
    def train_step(self, data):
        # forward propagation on gradient tape
        with tf.GradientTape() as tape:
            loss = self._compute_loss(data)

        # compute the loss gradients 
        grads = tape.gradient(loss, self.siamese_network.trainable_weights)

        # backproagation
        self.optimizer.apply_gradients(zip(grads,self.siamese_network.trainable_weights))

        # update the loss and accuracy metrics
        self.loss_tracker.update_state(loss)
        accuracy = self._compute_accuracy(data)
        self.accuracy_tracker.update_state(accuracy)

        return {"loss": self.loss_tracker.result(), "accuracy": self.accuracy_tracker.result()}
     

    # custom testing step
    def test_step(self, data):
        # update the loss metric.
        loss = self._compute_loss(data)
        self.loss_tracker.update_state(loss)
        # update accuracy metric
        accuracy = self._compute_accuracy(data)
        self.accuracy_tracker.update_state(accuracy)
        

        return {"loss": self.loss_tracker.result(), "accuracy": self.accuracy_tracker.result()}


    # define the triplet loss function
    def _compute_loss(self, data):
        # compute distance of anchor from positive and negative images
        ap_distance, an_distance = self.siamese_network(data)
        # compute the triplet loss (we want to minimize ap_distance and maximise an_distance,
        # which is why there's a minus sign infront of an_distance, we also allow for a small margin) 
        loss = ap_distance - an_distance + self.margin   
        # make sure the loss value is non-negative
        loss = tf.maximum(loss, 0.0)
        
        return loss
    

    def _compute_accuracy(self, data):
        # compute distance of anchor from positive and negative images
        ap_distance, an_distance = self.siamese_network(data)
        accuracy = tf.reduce_mean(tf.cast(ap_distance < an_distance, tf.float32))

        return accuracy


    @property
    def metrics(self):
        return [self.loss_tracker, self.accuracy_tracker]

# %% [markdown]
# #### Now, let's train this model

# %%
siamese_model = SiameseModel(siamese_network)
siamese_model.compile(optimizer=optimizers.Adam(learning_rate=0.00001))

# %%
# checkpoint callback
checkpoint_filepath = './siamese_model_dir'
#model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=True,monitor='val_loss',mode='min',save_best_only=True)
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, verbose=1, save_weights_only=True,monitor='loss',mode='min',save_best_only=False)

# %%
siamese_model.fit(train_dataset, epochs=5, validation_data=val_dataset, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/5
# 2256/2256 [==============================] - ETA: 0s - loss: 1.2259 - accuracy: 0.9912
# Epoch 1: saving model to ./siamese_model_dir
# 2256/2256 [==============================] - 829s 360ms/step - loss: 1.2259 - accuracy: 0.9912 - val_loss: 2.4822 - val_accuracy: 0.8755
# Epoch 2/5
# 2256/2256 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9993
# Epoch 2: saving model to ./siamese_model_dir
# 2256/2256 [==============================] - 809s 359ms/step - loss: 0.0436 - accuracy: 0.9993 - val_loss: 2.8428 - val_accuracy: 0.9151
# Epoch 3/5
#   46/2256 [..............................] - ETA: 11:10 - loss: 0.0520 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/tanzid/Code/UniMelb/Semester2/COMP_90086_Computer_Vision/Project/Code/siamese_net_3.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/tanzid/Code/UniMelb/Semester2/COMP_90086_Computer_Vision/Project/Code/siamese_net_3.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> siamese_model.fit(train_dataset, epochs=5, validation_data=val_dataset, callbacks=[model_checkpoint_callback])
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/keras/engine/training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tf_cv/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
siamese_model.load_weights(checkpoint_filepath)

# %% [markdown]
# #### Evaluating the trained siamese network on the validation dataset

# %%
# pick a sample triplet
sample = next(iter(val_dataset))
visualize(*sample)

# %% [markdown]
# #### Compute the l2 distance between the anchor and positive/negative images

# %%
anchor, positive, negative = sample

anchor_features, positive_features, negative_features = (feature_extractor(anchor), feature_extractor(positive), feature_extractor(negative))

# %%
mse = metrics.MeanSquaredError()

positive_distance = mse(anchor_features, positive_features)
negative_distance = mse(anchor_features, negative_features)

print(f"Dist(A,P) = {positive_distance.numpy()}, Dist(A,N) = {negative_distance.numpy()}")
# Out:
# Dist(A,P) = 0.8094030022621155, Dist(A,N) = 0.9343273639678955

# %%
def mean_squared_dist(vectors1, vectors2):
    diff = tf.square(vectors1 - vectors2)
    mean_squared_dist = tf.reduce_sum(diff, axis=1)
    return mean_squared_dist

# %%
print(tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# 565

# %%
num_correct = 0
for i, (anchor_batch, positive_batch, negative_batch) in enumerate(val_dataset):

    anchor_batch_features, positive_batch_features, negative_batch_features = (feature_extractor(anchor_batch), feature_extractor(positive_batch), feature_extractor(negative_batch))

    positive_distances = mean_squared_dist(anchor_batch_features, positive_batch_features)
    negative_distances = mean_squared_dist(anchor_batch_features, negative_batch_features)
    correct = tf.less(positive_distances, negative_distances)
    num_correct_batch = tf.reduce_sum(tf.cast(correct, tf.float32))
    num_correct += num_correct_batch
    
    print(f"Batch# {i}, batch accuracy = {num_correct_batch/batch_size}")

print(f"Accuracy = {num_correct/(batch_size*i)}")
# Out:
# Batch# 0, batch accuracy = 0.8125
# Batch# 1, batch accuracy = 0.875
# Batch# 2, batch accuracy = 0.6875
# Batch# 3, batch accuracy = 0.78125
# Batch# 4, batch accuracy = 0.75
# Batch# 5, batch accuracy = 0.6875
# Batch# 6, batch accuracy = 0.71875
# Batch# 7, batch accuracy = 0.875
# Batch# 8, batch accuracy = 0.8125
# Batch# 9, batch accuracy = 0.78125
# Batch# 10, batch accuracy = 0.75
# Batch# 11, batch accuracy = 0.96875
# Batch# 12, batch accuracy = 0.90625
# Batch# 13, batch accuracy = 0.90625
# Batch# 14, batch accuracy = 0.75
# Batch# 15, batch accuracy = 0.84375
# Batch# 16, batch accuracy = 0.90625
# Batch# 17, batch accuracy = 0.8125
# Batch# 18, batch accuracy = 0.8125
# Batch# 19, batch accuracy = 0.9375
# Batch# 20, batch accuracy = 0.75
# Batch# 21, batch accuracy = 0.8125
# Batch# 22, batch accuracy = 0.84375
# Batch# 23, batch accuracy = 0.96875
# Batch# 24, batch accuracy = 0.84375
# Batch# 25, batch accuracy = 0.8125
# Batch# 26, batch accuracy = 0.8125
# Batch# 27, batch accuracy = 0.875
# Batch# 28, batch accuracy = 0.8125
# Batch# 29, batch accuracy = 0.71875
# Batch# 30, batch accuracy = 0.8125
# Batch# 31, batch accuracy = 0.84375
# Batch# 32, batch accuracy = 0.78125
# Batch# 33, batch accuracy = 0.6875
# Batch# 34, batch accuracy = 0.71875
# Batch# 35, batch accuracy = 0.875
# Batch# 36, batch accuracy = 0.75
# Batch# 37, batch accuracy = 0.65625
# Batch# 38, batch accuracy = 0.71875
# Batch# 39, batch accuracy = 0.6875
# Batch# 40, batch accuracy = 0.875
# Batch# 41, batch accuracy = 0.625
# Batch# 42, batch accuracy = 0.78125
# Batch# 43, batch accuracy = 0.6875
# Batch# 44, batch accuracy = 0.75
# Batch# 45, batch accuracy = 0.6875
# Batch# 46, batch accuracy = 0.625
# Batch# 47, batch accuracy = 0.8125
# Batch# 48, batch accuracy = 0.78125
# Batch# 49, batch accuracy = 0.75
# Batch# 50, batch accuracy = 0.6875
# Batch# 51, batch accuracy = 0.75
# Batch# 52, batch accuracy = 0.75
# Batch# 53, batch accuracy = 0.84375
# Batch# 54, batch accuracy = 0.75
# Batch# 55, batch accuracy = 0.65625
# Batch# 56, batch accuracy = 0.75
# Batch# 57, batch accuracy = 0.84375
# Batch# 58, batch accuracy = 0.78125
# Batch# 59, batch accuracy = 0.84375
# Batch# 60, batch accuracy = 0.8125
# Batch# 61, batch accuracy = 0.84375
# Batch# 62, batch accuracy = 0.75
# Batch# 63, batch accuracy = 0.75
# Batch# 64, batch accuracy = 0.78125
# Batch# 65, batch accuracy = 0.84375
# Batch# 66, batch accuracy = 0.875
# Batch# 67, batch accuracy = 0.78125
# Batch# 68, batch accuracy = 0.78125
# Batch# 69, batch accuracy = 0.84375
# Batch# 70, batch accuracy = 0.84375
# Batch# 71, batch accuracy = 0.84375
# Batch# 72, batch accuracy = 0.8125
# Batch# 73, batch accuracy = 0.75
# Batch# 74, batch accuracy = 0.84375
# Batch# 75, batch accuracy = 0.84375
# Batch# 76, batch accuracy = 0.59375
# Batch# 77, batch accuracy = 0.71875
# Batch# 78, batch accuracy = 0.625
# Batch# 79, batch accuracy = 0.8125
# Batch# 80, batch accuracy = 0.71875
# Batch# 81, batch accuracy = 0.875
# Batch# 82, batch accuracy = 0.84375
# Batch# 83, batch accuracy = 0.875
# Batch# 84, batch accuracy = 0.78125
# Batch# 85, batch accuracy = 0.78125
# Batch# 86, batch accuracy = 0.5625
# Batch# 87, batch accuracy = 0.8125
# Batch# 88, batch accuracy = 0.8125
# Batch# 89, batch accuracy = 0.75
# Batch# 90, batch accuracy = 0.78125
# Batch# 91, batch accuracy = 0.8125
# Batch# 92, batch accuracy = 0.9375
# Batch# 93, batch accuracy = 0.8125
# Batch# 94, batch accuracy = 0.78125
# Batch# 95, batch accuracy = 0.84375
# Batch# 96, batch accuracy = 0.65625
# Batch# 97, batch accuracy = 0.84375
# Batch# 98, batch accuracy = 0.875
# Batch# 99, batch accuracy = 0.65625
# Batch# 100, batch accuracy = 0.75
# Batch# 101, batch accuracy = 0.6875
# Batch# 102, batch accuracy = 0.6875
# Batch# 103, batch accuracy = 0.6875
# Batch# 104, batch accuracy = 0.78125
# Batch# 105, batch accuracy = 0.84375
# Batch# 106, batch accuracy = 0.6875
# Batch# 107, batch accuracy = 0.8125
# Batch# 108, batch accuracy = 0.8125
# Batch# 109, batch accuracy = 0.71875
# Batch# 110, batch accuracy = 0.71875
# Batch# 111, batch accuracy = 0.71875
# Batch# 112, batch accuracy = 0.75
# Batch# 113, batch accuracy = 0.75
# Batch# 114, batch accuracy = 0.8125
# Batch# 115, batch accuracy = 0.78125
# Batch# 116, batch accuracy = 0.65625
# Batch# 117, batch accuracy = 0.71875
# Batch# 118, batch accuracy = 0.78125
# Batch# 119, batch accuracy = 0.6875
# Batch# 120, batch accuracy = 0.78125
# Batch# 121, batch accuracy = 0.75
# Batch# 122, batch accuracy = 0.78125
# Batch# 123, batch accuracy = 0.75
# Batch# 124, batch accuracy = 0.71875
# Batch# 125, batch accuracy = 0.8125
# Batch# 126, batch accuracy = 0.8125
# Batch# 127, batch accuracy = 0.75
# Batch# 128, batch accuracy = 0.84375
# Batch# 129, batch accuracy = 0.8125
# Batch# 130, batch accuracy = 0.84375
# Batch# 131, batch accuracy = 0.8125
# Batch# 132, batch accuracy = 0.84375
# Batch# 133, batch accuracy = 0.8125
# Batch# 134, batch accuracy = 0.8125
# Batch# 135, batch accuracy = 0.84375
# Batch# 136, batch accuracy = 0.8125
# Batch# 137, batch accuracy = 0.6875
# Batch# 138, batch accuracy = 0.8125
# Batch# 139, batch accuracy = 0.78125
# Batch# 140, batch accuracy = 0.78125
# Batch# 141, batch accuracy = 0.875
# Batch# 142, batch accuracy = 0.75
# Batch# 143, batch accuracy = 0.78125
# Batch# 144, batch accuracy = 0.6875
# Batch# 145, batch accuracy = 0.8125
# Batch# 146, batch accuracy = 0.84375
# Batch# 147, batch accuracy = 0.75
# Batch# 148, batch accuracy = 0.84375
# Batch# 149, batch accuracy = 0.78125
# Batch# 150, batch accuracy = 0.9375
# Batch# 151, batch accuracy = 0.78125
# Batch# 152, batch accuracy = 0.8125
# Batch# 153, batch accuracy = 0.59375
# Batch# 154, batch accuracy = 0.875
# Batch# 155, batch accuracy = 0.625
# Batch# 156, batch accuracy = 0.78125
# Batch# 157, batch accuracy = 0.78125
# Batch# 158, batch accuracy = 0.84375
# Batch# 159, batch accuracy = 0.8125
# Batch# 160, batch accuracy = 0.6875
# Batch# 161, batch accuracy = 0.90625
# Batch# 162, batch accuracy = 0.75
# Batch# 163, batch accuracy = 0.84375
# Batch# 164, batch accuracy = 0.8125
# Batch# 165, batch accuracy = 0.90625
# Batch# 166, batch accuracy = 0.78125
# Batch# 167, batch accuracy = 0.8125
# Batch# 168, batch accuracy = 0.78125
# Batch# 169, batch accuracy = 0.875
# Batch# 170, batch accuracy = 0.75
# Batch# 171, batch accuracy = 0.8125
# Batch# 172, batch accuracy = 0.84375
# Batch# 173, batch accuracy = 0.90625
# Batch# 174, batch accuracy = 0.71875
# Batch# 175, batch accuracy = 0.90625
# Batch# 176, batch accuracy = 0.84375
# Batch# 177, batch accuracy = 0.78125
# Batch# 178, batch accuracy = 0.875
# Batch# 179, batch accuracy = 0.875
# Batch# 180, batch accuracy = 0.84375
# Batch# 181, batch accuracy = 0.8125
# Batch# 182, batch accuracy = 0.90625
# Batch# 183, batch accuracy = 0.875
# Batch# 184, batch accuracy = 0.75
# Batch# 185, batch accuracy = 0.9375
# Batch# 186, batch accuracy = 0.9375
# Batch# 187, batch accuracy = 0.6875
# Batch# 188, batch accuracy = 0.78125
# Batch# 189, batch accuracy = 0.875
# Batch# 190, batch accuracy = 0.875
# Batch# 191, batch accuracy = 0.8125
# Batch# 192, batch accuracy = 0.6875
# Batch# 193, batch accuracy = 0.75
# Batch# 194, batch accuracy = 0.84375
# Batch# 195, batch accuracy = 0.75
# Batch# 196, batch accuracy = 0.78125
# Batch# 197, batch accuracy = 0.6875
# Batch# 198, batch accuracy = 0.84375
# Batch# 199, batch accuracy = 0.875
# Batch# 200, batch accuracy = 0.8125
# Batch# 201, batch accuracy = 0.875
# Batch# 202, batch accuracy = 0.84375
# Batch# 203, batch accuracy = 0.78125
# Batch# 204, batch accuracy = 0.8125
# Batch# 205, batch accuracy = 0.8125
# Batch# 206, batch accuracy = 0.84375
# Batch# 207, batch accuracy = 0.875
# Batch# 208, batch accuracy = 0.8125
# Batch# 209, batch accuracy = 0.875
# Batch# 210, batch accuracy = 0.84375
# Batch# 211, batch accuracy = 0.78125
# Batch# 212, batch accuracy = 0.84375
# Batch# 213, batch accuracy = 0.71875
# Batch# 214, batch accuracy = 0.8125
# Batch# 215, batch accuracy = 0.75
# Batch# 216, batch accuracy = 0.84375
# Batch# 217, batch accuracy = 0.78125
# Batch# 218, batch accuracy = 0.75
# Batch# 219, batch accuracy = 0.84375
# Batch# 220, batch accuracy = 0.75
# Batch# 221, batch accuracy = 0.78125
# Batch# 222, batch accuracy = 0.6875
# Batch# 223, batch accuracy = 0.875
# Batch# 224, batch accuracy = 0.78125
# Batch# 225, batch accuracy = 0.75
# Batch# 226, batch accuracy = 0.8125
# Batch# 227, batch accuracy = 0.75
# Batch# 228, batch accuracy = 0.8125
# Batch# 229, batch accuracy = 0.84375
# Batch# 230, batch accuracy = 0.6875
# Batch# 231, batch accuracy = 0.71875
# Batch# 232, batch accuracy = 0.8125
# Batch# 233, batch accuracy = 0.65625
# Batch# 234, batch accuracy = 0.78125
# Batch# 235, batch accuracy = 0.84375
# Batch# 236, batch accuracy = 0.6875
# Batch# 237, batch accuracy = 0.78125
# Batch# 238, batch accuracy = 0.75
# Batch# 239, batch accuracy = 0.78125
# Batch# 240, batch accuracy = 0.8125
# Batch# 241, batch accuracy = 0.59375
# Batch# 242, batch accuracy = 0.65625
# Batch# 243, batch accuracy = 0.875
# Batch# 244, batch accuracy = 0.6875
# Batch# 245, batch accuracy = 0.84375
# Batch# 246, batch accuracy = 0.78125
# Batch# 247, batch accuracy = 0.84375
# Batch# 248, batch accuracy = 0.78125
# Batch# 249, batch accuracy = 0.78125
# Batch# 250, batch accuracy = 0.9375
# Batch# 251, batch accuracy = 0.875
# Batch# 252, batch accuracy = 0.8125
# Batch# 253, batch accuracy = 0.78125
# Batch# 254, batch accuracy = 0.75
# Batch# 255, batch accuracy = 0.6875
# Batch# 256, batch accuracy = 0.65625
# Batch# 257, batch accuracy = 0.90625
# Batch# 258, batch accuracy = 0.65625
# Batch# 259, batch accuracy = 0.84375
# Batch# 260, batch accuracy = 0.75
# Batch# 261, batch accuracy = 0.71875
# Batch# 262, batch accuracy = 0.71875
# Batch# 263, batch accuracy = 0.8125
# Batch# 264, batch accuracy = 0.78125
# Batch# 265, batch accuracy = 0.78125
# Batch# 266, batch accuracy = 0.84375
# Batch# 267, batch accuracy = 0.625
# Batch# 268, batch accuracy = 0.84375
# Batch# 269, batch accuracy = 0.90625
# Batch# 270, batch accuracy = 0.8125
# Batch# 271, batch accuracy = 0.75
# Batch# 272, batch accuracy = 0.8125
# Batch# 273, batch accuracy = 0.84375
# Batch# 274, batch accuracy = 0.8125
# Batch# 275, batch accuracy = 0.8125
# Batch# 276, batch accuracy = 0.875
# Batch# 277, batch accuracy = 0.8125
# Batch# 278, batch accuracy = 0.78125
# Batch# 279, batch accuracy = 0.8125
# Batch# 280, batch accuracy = 0.875
# Batch# 281, batch accuracy = 0.8125
# Batch# 282, batch accuracy = 0.90625
# Batch# 283, batch accuracy = 0.8125
# Batch# 284, batch accuracy = 0.84375
# Batch# 285, batch accuracy = 0.8125
# Batch# 286, batch accuracy = 0.78125
# Batch# 287, batch accuracy = 0.84375
# Batch# 288, batch accuracy = 0.71875
# Batch# 289, batch accuracy = 0.71875
# Batch# 290, batch accuracy = 0.6875
# Batch# 291, batch accuracy = 0.75
# Batch# 292, batch accuracy = 0.75
# Batch# 293, batch accuracy = 0.75
# Batch# 294, batch accuracy = 0.84375
# Batch# 295, batch accuracy = 0.78125
# Batch# 296, batch accuracy = 0.84375
# Batch# 297, batch accuracy = 0.8125
# Batch# 298, batch accuracy = 0.71875
# Batch# 299, batch accuracy = 0.875
# Batch# 300, batch accuracy = 0.8125
# Batch# 301, batch accuracy = 0.8125
# Batch# 302, batch accuracy = 0.625
# Batch# 303, batch accuracy = 0.46875
# Batch# 304, batch accuracy = 0.75
# Batch# 305, batch accuracy = 0.75
# Batch# 306, batch accuracy = 0.65625
# Batch# 307, batch accuracy = 0.6875
# Batch# 308, batch accuracy = 0.78125
# Batch# 309, batch accuracy = 0.78125
# Batch# 310, batch accuracy = 0.84375
# Batch# 311, batch accuracy = 0.6875
# Batch# 312, batch accuracy = 0.71875
# Batch# 313, batch accuracy = 0.78125
# Batch# 314, batch accuracy = 0.8125
# Batch# 315, batch accuracy = 0.71875
# Batch# 316, batch accuracy = 0.78125
# Batch# 317, batch accuracy = 0.6875
# Batch# 318, batch accuracy = 0.84375
# Batch# 319, batch accuracy = 0.8125
# Batch# 320, batch accuracy = 0.8125
# Batch# 321, batch accuracy = 0.75
# Batch# 322, batch accuracy = 0.75
# Batch# 323, batch accuracy = 0.84375
# Batch# 324, batch accuracy = 0.71875
# Batch# 325, batch accuracy = 0.875
# Batch# 326, batch accuracy = 0.9375
# Batch# 327, batch accuracy = 0.84375
# Batch# 328, batch accuracy = 0.8125
# Batch# 329, batch accuracy = 0.75
# Batch# 330, batch accuracy = 0.875
# Batch# 331, batch accuracy = 0.8125
# Batch# 332, batch accuracy = 0.84375
# Batch# 333, batch accuracy = 0.90625
# Batch# 334, batch accuracy = 0.71875
# Batch# 335, batch accuracy = 0.75
# Batch# 336, batch accuracy = 0.5625
# Batch# 337, batch accuracy = 0.78125
# Batch# 338, batch accuracy = 0.65625
# Batch# 339, batch accuracy = 0.75
# Batch# 340, batch accuracy = 0.75
# Batch# 341, batch accuracy = 0.8125
# Batch# 342, batch accuracy = 0.6875
# Batch# 343, batch accuracy = 0.78125
# Batch# 344, batch accuracy = 0.84375
# Batch# 345, batch accuracy = 0.84375
# Batch# 346, batch accuracy = 0.75
# Batch# 347, batch accuracy = 0.78125
# Batch# 348, batch accuracy = 0.8125
# Batch# 349, batch accuracy = 0.84375
# Batch# 350, batch accuracy = 0.875
# Batch# 351, batch accuracy = 0.84375
# Batch# 352, batch accuracy = 0.75
# Batch# 353, batch accuracy = 0.71875
# Batch# 354, batch accuracy = 0.75
# Batch# 355, batch accuracy = 0.625
# Batch# 356, batch accuracy = 0.78125
# Batch# 357, batch accuracy = 0.71875
# Batch# 358, batch accuracy = 0.65625
# Batch# 359, batch accuracy = 0.78125
# Batch# 360, batch accuracy = 0.78125
# Batch# 361, batch accuracy = 0.65625
# Batch# 362, batch accuracy = 0.78125
# Batch# 363, batch accuracy = 0.8125
# Batch# 364, batch accuracy = 0.8125
# Batch# 365, batch accuracy = 0.78125
# Batch# 366, batch accuracy = 0.75
# Batch# 367, batch accuracy = 0.8125
# Batch# 368, batch accuracy = 0.78125
# Batch# 369, batch accuracy = 0.6875
# Batch# 370, batch accuracy = 0.65625
# Batch# 371, batch accuracy = 0.71875
# Batch# 372, batch accuracy = 0.8125
# Batch# 373, batch accuracy = 0.78125
# Batch# 374, batch accuracy = 0.78125
# Batch# 375, batch accuracy = 0.78125
# Batch# 376, batch accuracy = 0.875
# Batch# 377, batch accuracy = 0.71875
# Batch# 378, batch accuracy = 0.8125
# Batch# 379, batch accuracy = 0.625
# Batch# 380, batch accuracy = 0.84375
# Batch# 381, batch accuracy = 0.90625
# Batch# 382, batch accuracy = 0.78125
# Batch# 383, batch accuracy = 0.8125
# Batch# 384, batch accuracy = 0.875
# Batch# 385, batch accuracy = 0.78125
# Batch# 386, batch accuracy = 0.78125
# Batch# 387, batch accuracy = 0.75
# Batch# 388, batch accuracy = 0.65625
# Batch# 389, batch accuracy = 0.78125
# Batch# 390, batch accuracy = 0.75
# Batch# 391, batch accuracy = 0.6875
# Batch# 392, batch accuracy = 0.8125
# Batch# 393, batch accuracy = 0.6875
# Batch# 394, batch accuracy = 0.875
# Batch# 395, batch accuracy = 0.71875
# Batch# 396, batch accuracy = 0.75
# Batch# 397, batch accuracy = 0.84375
# Batch# 398, batch accuracy = 0.6875
# Batch# 399, batch accuracy = 0.8125
# Batch# 400, batch accuracy = 0.71875
# Batch# 401, batch accuracy = 0.84375
# Batch# 402, batch accuracy = 0.6875
# Batch# 403, batch accuracy = 0.78125
# Batch# 404, batch accuracy = 0.78125
# Batch# 405, batch accuracy = 0.84375
# Batch# 406, batch accuracy = 0.59375
# Batch# 407, batch accuracy = 0.875
# Batch# 408, batch accuracy = 0.75
# Batch# 409, batch accuracy = 0.6875
# Batch# 410, batch accuracy = 0.90625
# Batch# 411, batch accuracy = 0.875
# Batch# 412, batch accuracy = 0.875
# Batch# 413, batch accuracy = 0.6875
# Batch# 414, batch accuracy = 0.84375
# Batch# 415, batch accuracy = 0.78125
# Batch# 416, batch accuracy = 0.84375
# Batch# 417, batch accuracy = 0.84375
# Batch# 418, batch accuracy = 0.8125
# Batch# 419, batch accuracy = 0.75
# Batch# 420, batch accuracy = 0.9375
# Batch# 421, batch accuracy = 0.71875
# Batch# 422, batch accuracy = 0.875
# Batch# 423, batch accuracy = 0.90625
# Batch# 424, batch accuracy = 0.8125
# Batch# 425, batch accuracy = 0.8125
# Batch# 426, batch accuracy = 0.84375
# Batch# 427, batch accuracy = 0.875
# Batch# 428, batch accuracy = 0.78125
# Batch# 429, batch accuracy = 0.90625
# Batch# 430, batch accuracy = 0.75
# Batch# 431, batch accuracy = 0.75
# Batch# 432, batch accuracy = 0.9375
# Batch# 433, batch accuracy = 0.71875
# Batch# 434, batch accuracy = 0.9375
# Batch# 435, batch accuracy = 0.84375
# Batch# 436, batch accuracy = 0.78125
# Batch# 437, batch accuracy = 0.875
# Batch# 438, batch accuracy = 0.75
# Batch# 439, batch accuracy = 0.84375
# Batch# 440, batch accuracy = 0.84375
# Batch# 441, batch accuracy = 0.875
# Batch# 442, batch accuracy = 0.84375
# Batch# 443, batch accuracy = 0.84375
# Batch# 444, batch accuracy = 0.75
# Batch# 445, batch accuracy = 0.75
# Batch# 446, batch accuracy = 0.8125
# Batch# 447, batch accuracy = 0.625
# Batch# 448, batch accuracy = 0.84375
# Batch# 449, batch accuracy = 0.8125
# Batch# 450, batch accuracy = 0.65625
# Batch# 451, batch accuracy = 0.875
# Batch# 452, batch accuracy = 0.65625
# Batch# 453, batch accuracy = 0.78125
# Batch# 454, batch accuracy = 0.71875
# Batch# 455, batch accuracy = 0.8125
# Batch# 456, batch accuracy = 0.75
# Batch# 457, batch accuracy = 0.78125
# Batch# 458, batch accuracy = 0.84375
# Batch# 459, batch accuracy = 0.75
# Batch# 460, batch accuracy = 0.6875
# Batch# 461, batch accuracy = 0.78125
# Batch# 462, batch accuracy = 0.84375
# Batch# 463, batch accuracy = 0.84375
# Batch# 464, batch accuracy = 0.84375
# Batch# 465, batch accuracy = 0.84375
# Batch# 466, batch accuracy = 0.875
# Batch# 467, batch accuracy = 0.84375
# Batch# 468, batch accuracy = 0.8125
# Batch# 469, batch accuracy = 0.875
# Batch# 470, batch accuracy = 0.84375
# Batch# 471, batch accuracy = 0.8125
# Batch# 472, batch accuracy = 0.78125
# Batch# 473, batch accuracy = 0.875
# Batch# 474, batch accuracy = 0.8125
# Batch# 475, batch accuracy = 0.71875
# Batch# 476, batch accuracy = 0.8125
# Batch# 477, batch accuracy = 0.8125
# Batch# 478, batch accuracy = 0.84375
# Batch# 479, batch accuracy = 0.75
# Batch# 480, batch accuracy = 0.8125
# Batch# 481, batch accuracy = 0.75
# Batch# 482, batch accuracy = 0.78125
# Batch# 483, batch accuracy = 0.8125
# Batch# 484, batch accuracy = 0.78125
# Batch# 485, batch accuracy = 0.71875
# Batch# 486, batch accuracy = 0.78125
# Batch# 487, batch accuracy = 0.78125
# Batch# 488, batch accuracy = 0.84375
# Batch# 489, batch accuracy = 0.6875
# Batch# 490, batch accuracy = 0.84375
# Batch# 491, batch accuracy = 0.71875
# Batch# 492, batch accuracy = 0.8125
# Batch# 493, batch accuracy = 0.90625
# Batch# 494, batch accuracy = 0.84375
# Batch# 495, batch accuracy = 0.875
# Batch# 496, batch accuracy = 0.75
# Batch# 497, batch accuracy = 0.8125
# Batch# 498, batch accuracy = 0.84375
# Batch# 499, batch accuracy = 0.6875
# Batch# 500, batch accuracy = 0.75
# Batch# 501, batch accuracy = 0.75
# Batch# 502, batch accuracy = 0.78125
# Batch# 503, batch accuracy = 0.8125
# Batch# 504, batch accuracy = 0.90625
# Batch# 505, batch accuracy = 0.8125
# Batch# 506, batch accuracy = 0.84375
# Batch# 507, batch accuracy = 0.75
# Batch# 508, batch accuracy = 0.78125
# Batch# 509, batch accuracy = 0.875
# Batch# 510, batch accuracy = 0.625
# Batch# 511, batch accuracy = 0.84375
# Batch# 512, batch accuracy = 0.84375
# Batch# 513, batch accuracy = 0.78125
# Batch# 514, batch accuracy = 0.75
# Batch# 515, batch accuracy = 0.78125
# Batch# 516, batch accuracy = 0.6875
# Batch# 517, batch accuracy = 0.84375
# Batch# 518, batch accuracy = 0.78125
# Batch# 519, batch accuracy = 0.84375
# Batch# 520, batch accuracy = 0.84375
# Batch# 521, batch accuracy = 0.84375
# Batch# 522, batch accuracy = 0.78125
# Batch# 523, batch accuracy = 0.8125
# Batch# 524, batch accuracy = 0.84375
# Batch# 525, batch accuracy = 0.90625
# Batch# 526, batch accuracy = 0.78125
# Batch# 527, batch accuracy = 0.78125
# Batch# 528, batch accuracy = 0.9375
# Batch# 529, batch accuracy = 0.6875
# Batch# 530, batch accuracy = 0.90625
# Batch# 531, batch accuracy = 0.75
# Batch# 532, batch accuracy = 0.8125
# Batch# 533, batch accuracy = 0.6875
# Batch# 534, batch accuracy = 0.84375
# Batch# 535, batch accuracy = 0.84375
# Batch# 536, batch accuracy = 0.8125
# Batch# 537, batch accuracy = 0.875
# Batch# 538, batch accuracy = 0.78125
# Batch# 539, batch accuracy = 0.84375
# Batch# 540, batch accuracy = 0.75
# Batch# 541, batch accuracy = 0.71875
# Batch# 542, batch accuracy = 0.84375
# Batch# 543, batch accuracy = 0.96875
# Batch# 544, batch accuracy = 0.8125
# Batch# 545, batch accuracy = 0.8125
# Batch# 546, batch accuracy = 0.875
# Batch# 547, batch accuracy = 0.875
# Batch# 548, batch accuracy = 0.78125
# Batch# 549, batch accuracy = 0.8125
# Batch# 550, batch accuracy = 0.84375
# Batch# 551, batch accuracy = 0.84375
# Batch# 552, batch accuracy = 0.78125
# Batch# 553, batch accuracy = 0.84375
# Batch# 554, batch accuracy = 0.84375
# Batch# 555, batch accuracy = 0.875
# Batch# 556, batch accuracy = 0.875
# Batch# 557, batch accuracy = 0.84375
# Batch# 558, batch accuracy = 0.84375
# Batch# 559, batch accuracy = 0.8125
# Batch# 560, batch accuracy = 0.84375
# Batch# 561, batch accuracy = 0.8125
# Batch# 562, batch accuracy = 0.84375
# Batch# 563, batch accuracy = 0.875
# Batch# 564, batch accuracy = 0.3125
# Accuracy = 0.7918882966041565

# %% [markdown]
# #### Maybe try changing the negative images in each training triplet to images that are more similar to the anchor, i.e. these are the harder negative images. This should force the network to learn better representations.
